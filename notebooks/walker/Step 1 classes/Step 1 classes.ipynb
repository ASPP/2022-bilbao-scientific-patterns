# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

from walker import Walker, plot_trajectory

# from walker import ??? # Make sure to import your changed code in the right way :)

# %% [markdown]
# # 1. Reformat the code in 'walker.py' from functions to a class
# Think about
# - which variables should be attributes?
# - how should the setup/initialization work?
# - Which functions and attributes should be part of the class?

# %% [markdown]
# # 2. Simulate a trajectory

# %%
# Create a Walker instance
# Remove?
walker = Walker(sigma_i=3, sigma_j=4, size=200, map_type='hills')

# Sample a next step 1000 times
i, j = 100, 50
trajectory = []
for _ in range(1000):
    i, j = walker.sample_next_step(i, j)
    trajectory.append((i, j))

# %%
plot_trajectory(trajectory, walker.context_map)
